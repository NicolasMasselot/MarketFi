# %%
import sys
sys.path.append("../src")

from greeks import param

# %%
import numpy as np
import matplotlib.pyplot as plt
S_values = np.linspace(50, 150, 100)
K = 100
T = 1
r = 0.05
sigma = 0.2
delta_call = [param(S0, K, T, r, sigma)[0] for S0 in S_values]
plt.plot(S_values,delta_call)
plt.xlabel("Spot Price (S0)")
plt.ylabel("Delta Call") 
plt.title("Delta Call vs Spot Price")
plt.grid(True)
plt.show()

# %%
S_values = np.linspace(50, 150, 100)
K = 120
T = 2
r = 0.03
sigma = 0.25
delta_put = [param(S0, K, T, r, sigma)[1] for S0 in S_values]
plt.plot(S_values,delta_put)
plt.xlabel("Spot Price (S0)")
plt.ylabel("Delta Put") 
plt.title("Delta Put vs Spot Price")
plt.grid(True)
plt.show()

# %%
S_values = np.linspace(50, 150, 100)
K = 90
T = 1
r = 0.02
sigma = 0.3
gamma = [param(S0, K, T, r, sigma)[2] for S0 in S_values]
plt.plot(S_values,gamma)
plt.xlabel("Spot Price (S0)")
plt.ylabel("Gamma") 
plt.title("Gamma vs Spot Price")
plt.grid(True)
plt.show()

# %%
S_values = np.linspace(50, 150, 100)
K = 100
T = 1.5
r = 0.07
sigma = 0.15
vega = [param(S0, K, T, r, sigma)[3] for S0 in S_values]
plt.plot(S_values,vega)
plt.xlabel("Spot Price (S0)")
plt.ylabel("Vega") 
plt.title("Vega vs Spot Price")
plt.grid(True)
plt.show()
